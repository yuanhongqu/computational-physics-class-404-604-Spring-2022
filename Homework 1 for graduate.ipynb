# %%
import numpy as np
import matplotlib.pyplot as plt
import pylab as pl
from sympy import *

# %%
x=symbols("x")

# %%
i=1
n=11
sum=np.pi/2
while(i<n+1):
    sum=sum+2*sin(i*x)/i
    i=i+2

# %%
g=integrate(sum,x)
print(g)
# Out:
# 1.5707963267949*x - 2*cos(x) - 2*cos(3*x)/9 - 2*cos(5*x)/25 - 2*cos(7*x)/49 - 2*cos(9*x)/81 - 2*cos(11*x)/121

# %%
x=-np.pi
a=1.5707963267949*x-2*np.cos(x)-2*np.cos(3*x)/9-2*np.cos(5*x)/25-2*np.cos(7*x)/49-2*np.cos(9*x)/81-2*np.cos(11*x)/121
print(a)
# Out:
# -2.550543368147329

# %%
x=np.arange(-np.pi,np.pi,0.001)
m=1.5707963267949*x-2*np.cos(x)-2*np.cos(3*x)/9-2*np.cos(5*x)/25-2*np.cos(7*x)/49-2*np.cos(9*x)/81-2*np.cos(11*x)/121-a

plt.figure(figsize=(10,8))
ax=pl.gca()
plt.xlabel(r"$x$",fontsize=27)
plt.ylabel(r"$m(x)$",fontsize=27)
plt.tick_params(labelsize=20)

plt.plot(x,m)
