# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
xmin = -10.0   # left boundary
xmax = +10.0   # right boundary
Nx = 101       # number of grid points (including boundary)
tend = 10.0    # end time
dtout = 1.0    # time interval for outputs
x = np.linspace(xmin, xmax, Nx)
dx = (xmax - xmin) / (Nx - 1)
dt = 0.8 * dx
U = np.zeros(Nx,)
t = 0.0
U = 0.2 + 0.8 * np.exp(-0.5 * x**2)
tp = [t]
Up = np.copy(U)
fig = plt.figure(figsize=(16,10))
ax = fig.gca()
ax.plot(x, U, label=r"$t = {:.3G}$".format(t))
ax.set_xlabel(r"Position $x$")
ax.set_ylabel(r"$U(t,x)$")
ax.minorticks_on()
tout = t + dtout
while t < tend:
    Uold = np.copy(U)
    for ix in range(1, Nx - 1):
        U[ix]=Uold[ix]-Uold[ix]*dt*((Uold[ix]-Uold[ix-1])/dx)             
    t += dt
    if t >= tout:
        plt.plot(x, U, label=r"$t = {:.3G}$".format(t))
        tp.append(t)
        Up = np.vstack((Up, U))
        print("t = ", t)
        tout += dtout
ax.legend()
t, x = np.meshgrid(tp, x)
fig3D = plt.figure(figsize=(16,10))
ax3D = Axes3D(fig3D)
ax3D.plot_wireframe(t, x, Up.transpose(), color="red")
ax3D.set_xlabel("Time $t$")
ax3D.set_ylabel("Position $x$")
ax3D.set_zlabel(r"$U(t,x)$")
plt.show()
# Out:
# t =  1.12
# t =  2.080000000000001
# t =  3.040000000000002
# t =  4.000000000000003
# t =  5.120000000000004
# t =  6.0800000000000045
# t =  7.040000000000005
# t =  8.000000000000005
# t =  9.120000000000006
# t =  10.080000000000007

# %%
xmin = -10.0   # left boundary
xmax = +10.0   # right boundary
tend = 10.0    # end time
dtout = 1.0    # time interval for outputs
Nx = 1001       # number of grid points (including boundary)

x = np.linspace(xmin, xmax, Nx)
dx = (xmax - xmin) / (Nx - 1)
dt = 0.8 * dx
U = np.zeros(Nx,)

t = 0.0
U = 0.2 + 0.8 * np.exp(-0.5 * x**2)

tp = [t]
Up = np.copy(U)

fig = plt.figure(figsize=(16,10))
ax = fig.gca()
ax.plot(x, U, label=r"$t = {:.3G}$".format(t))
ax.set_xlabel(r"Position $x$")
ax.set_ylabel(r"$U(t,x)$")
ax.set_title("Grid size = 1001")
ax.minorticks_on()

tout = t + dtout
while t < tend:
    # Backup the previous time step.
    Uold = np.copy(U)

    # Find the state at the next time step.
    for ix in range(1, Nx - 1):
        U[ix]=Uold[ix]-Uold[ix]*dt*((Uold[ix]-Uold[ix-1])/dx) 
            
    t += dt

    # Save the data after every dtout.
    if t >= tout:
        plt.plot(x, U, label=r"$t = {:.3G}$".format(t))
        tp.append(t)
        Up = np.vstack((Up, U))
        print("t = ", t)
        tout += dtout

ax.legend()
t, x = np.meshgrid(tp, x)
fig3D = plt.figure(figsize=(16,10))
ax3D = Axes3D(fig3D)
ax3D.plot_wireframe(t, x, Up.transpose(), color="red")
ax3D.set_xlabel("Time $t$")
ax3D.set_ylabel("Position $x$")
ax3D.set_zlabel(r"$U(t,x)$")
ax3D.set_title("Grid size = 1001")
plt.show()

Nx = 11       # number of grid points (including boundary)
x = np.linspace(xmin, xmax, Nx)
dx = (xmax - xmin) / (Nx - 1)
dt = 0.8 * dx
U = np.zeros(Nx,)
t = 0.0
U = 0.2 + 0.8 * np.exp(-0.5 * x**2)

tp = [t]
Up = np.copy(U)

fig = plt.figure(figsize=(16,10))
ax = fig.gca()
ax.plot(x, U, label=r"$t = {:.3G}$".format(t))
ax.set_xlabel(r"Position $x$")
ax.set_ylabel(r"$U(t,x)$")
ax.set_title("Grid Size = 11")
ax.minorticks_on()
tout = t + dtout
while t < tend:
    Uold = np.copy(U)
    for ix in range(1, Nx - 1):
        U[ix]=Uold[ix]-Uold[ix]*dt*((Uold[ix]-Uold[ix-1])/dx) 
    t += dt
    if t >= tout:
        plt.plot(x, U, label=r"$t = {:.3G}$".format(t))
        tp.append(t)
        Up = np.vstack((Up, U))
        print("t = ", t)
        tout += dtout

ax.legend()
t, x = np.meshgrid(tp, x)
fig3D = plt.figure(figsize=(16,10))
ax3D = Axes3D(fig3D)
ax3D.plot_wireframe(t, x, Up.transpose(), color="red")
ax3D.set_xlabel("Time $t$")
ax3D.set_ylabel("Position $x$")
ax3D.set_zlabel(r"$U(t,x)$")
ax3D.set_title("Grid Size = 11")

print("Done.")
plt.show()
Nx = 10001       # number of grid points (including boundary)
x = np.linspace(xmin, xmax, Nx)
dx = (xmax - xmin) / (Nx - 1)
dt = 0.8 * dx
U = np.zeros(Nx,)
t = 0.0
U = 0.2 + 0.8 * np.exp(-0.5 * x**2)
tp = [t]
Up = np.copy(U)
fig = plt.figure(figsize=(16,10))
ax = fig.gca()
ax.plot(x, U, label=r"$t = {:.3G}$".format(t))
ax.set_xlabel(r"Position $x$")
ax.set_ylabel(r"$U(t,x)$")
ax.set_title("Grid Size = 10001")
ax.minorticks_on()
tout = t + dtout
while t < tend:
    Uold = np.copy(U)
    for ix in range(1, Nx - 1):
        U[ix]=Uold[ix]-Uold[ix]*dt*((Uold[ix]-Uold[ix-1])/dx)             
    t += dt
    if t >= tout:
        plt.plot(x, U, label=r"$t = {:.3G}$".format(t))
        tp.append(t)
        Up = np.vstack((Up, U))
        print("t = ", t)
        tout += dtout
ax.legend()
t, x = np.meshgrid(tp, x)

fig3D = plt.figure(figsize=(16,10))
ax3D = Axes3D(fig3D)
ax3D.plot_wireframe(t, x, Up.transpose(), color="red")
ax3D.set_xlabel("Time $t$")
ax3D.set_ylabel("Position $x$")
ax3D.set_zlabel(r"$U(t,x)$")
ax3D.set_title("Grid size = 10001")
plt.show()
# Out:
# t =  1.0080000000000007
# t =  2.0000000000000013
# t =  3.0080000000000022
# t =  4.000000000000003
# t =  5.008000000000004
# t =  6.000000000000004
# t =  7.008000000000005
# t =  8.000000000000005
# t =  9.008000000000006
# t =  10.000000000000007
# t =  1.6
# t =  3.2
# t =  4.800000000000001
# t =  6.4
# t =  8.0
# t =  9.6
# t =  11.2
# Done.
# t =  1.0000000000000122
# t =  2.000000000000041
# t =  3.0015999999999305
# t =  4.00159999999982
# t =  5.00159999999971
# t =  6.0015999999996
# t =  7.00159999999949
# t =  8.00159999999938
# t =  9.00159999999927
# t =  10.00159999999916
